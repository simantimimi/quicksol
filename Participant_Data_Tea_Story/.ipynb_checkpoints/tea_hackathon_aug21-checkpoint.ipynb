# %%
import os,sys
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("train.csv")
train_data.sample(10)
# Out:
#     WeekEnding_Date Kolkata_Average_Price Kolkata_Ref_Price  \
# 240        03/08/13                 147.6            152.58
# 488        05/05/18                156.77            148.71
# 455        23/09/17                162.78            149.87
# 186        28/07/12                 154.8            125.85
# 238        20/07/13                153.68            154.41
# 314        10/01/15                144.55            136.13
# 454        16/09/17                153.92             150.2
# 246        14/09/13                145.36            149.61
# 287        05/07/14                 186.1            158.62
# 216        23/02/13                133.19             99.14
#
#     Bangalore_Average_Price Bangalore_Ref_Price Cochin_Average_Price  \
# 240                  140.94              143.48               121.56
# 488                  154.72              142.07               134.86
# 455                   153.7              139.27               127.38
# ...

# %%
train_m = train_data.convert_objects(convert_numeric=True)
train_m.replace('NaN',0)
train_m
# Out:
# C:\Users\amit\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#     WeekEnding_Date  Kolkata_Average_Price  Kolkata_Ref_Price  \
# 0          03/01/09                  99.01              79.79
# 1          10/01/09                  97.74              78.73
# 2          17/01/09                  95.95              71.01
# 3          24/01/09                  94.14              73.38
# 4          31/01/09                  91.45              70.39
# 5          07/02/09                  88.99              70.40
# 6          14/02/09                  87.95              67.81
# 7          21/02/09                  84.39              65.69
# ...
